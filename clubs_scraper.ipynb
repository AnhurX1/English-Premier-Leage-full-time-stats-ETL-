# %%
import httpx
from dataclasses import dataclass, asdict
import pandas as pd
from openpyxl.workbook import Workbook
import os

# %%
@dataclass
class ClubStats:
    cleanSheets: int
    ownGoals: int
    yellowCards: int
    redCards: int
    fouls: int
    offsides: int
    passes: int
    shots: int
    shotsOnTarget: int
    hitWoodwork: int
    penaltiesScored: int

# %%
@dataclass
class ClubData:
    name: str
    position: int
    stadium: str
    capacity: int
    city: str
    #home_data
    home_played: int
    home_won: int
    home_drawn: int
    home_lost: int
    home_goalsFor: int
    home_goalsAgainst: int
    home_points: int

    #away_data
    away_played: int
    away_won: int
    away_drawn: int
    away_lost: int
    away_goalsFor: int
    away_goalsAgainst: int
    away_points: int

    #overall_data
    played: int
    won: int
    drawn: int
    lost: int
    goalsFor: int
    goalsAgainst: int
    points: int

# %%
def get_ClubData():
    url = "https://footballapi.pulselive.com/football/standings"
    querystring = {
    "altIds": "true",
    "detail": "1",
    "FOOTBALL_COMPETITION": "1",
    "comps": "1"
    }
    headers = {
    "accept": "*/*",
    "accept-language": "en-US,en;q=0.9",
    "content-type": "application/x-www-form-urlencoded; charset=UTF-8",
    "^if-none-match": "W/^0fd4c028efcbfea9a8933c1f4030985fc^^",
    "origin": "https://www.premierleague.com",
    "referer": "https://www.premierleague.com/",
    "^sec-ch-ua": "^Microsoft",
    "sec-ch-ua-mobile": "?0",
    "^sec-ch-ua-platform": "^Windows^^",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "cross-site",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36 Edg/123.0.0.0"
    }

    try:
        response = httpx.get(url, headers=headers, params=querystring, timeout= 10)
        return response.json()['tables'][0]['entries']
    except httpx.TimeoutException:
        print("Request timed out.")

get_ClubData()
# Out:
# [{'team': {'name': 'Manchester United',
#    'club': {'name': 'Manchester United',
#     'shortName': 'Man Utd',
#     'abbr': 'MUN',
#     'id': 12},
#    'teamType': 'FIRST',
#    'shortName': 'Man Utd',
#    'id': 12,
#    'altIds': {'opta': 't1'}},
#   'position': 1,
#   'startingPosition': 1,
#   'overall': {'played': 1221,
#    'won': 741,
#    'drawn': 267,
#    'lost': 213,
#    'goalsFor': 2288,
#    'goalsAgainst': 1155,
#    'goalsDifference': 1133,
#    'points': 2490},
#   'home': {'played': 610,
#    'won': 425,
#    'drawn': 115,
#    'lost': 70,
#    'goalsFor': 1273,
#    'goalsAgainst': 460,
#    'goalsDifference': 813,
#    'points': 1390},
#   'away': {'played': 611,
#    'won': 316,
#    'drawn': 152,
#    'lost': 143,
#    'goalsFor': 1015,
#    'goalsAgainst': 695,
#    'goalsDifference': 320,
#    'points': 1100},
#   'ground': {'name': 'Old Trafford',
#    'city': 'Manchester',
#    'capacity': 75635,
#    'location': {'latitude': 53.4626, 'longitude': -2.29103},
#    'source': 'OPTA',
#    'id': 42}},
#  {'team': {'name': 'Arsenal',
#    'club': {'name': 'Arsenal', 'shortName': 'Arsenal', 'abbr': 'ARS', 'id': 1},
#    'teamType': 'FIRST',
#    'shortName': 'Arsenal',
#    'id': 1,
#    'altIds': {'opta': 't3'}},
#   'position': 2,
#   'startingPosition': 2,
#   'overall': {'played': 1221,
#    'won': 667,
#    'drawn': 295,
#    'lost': 259,
#    'goalsFor': 2180,
#    'goalsAgainst': 1215,
#    'goalsDifference': 965,
#    'points': 2296},
#   'home': {'played': 610,
#    'won': 394,
#    'drawn': 136,
#    'lost': 80,
#    'goalsFor': 1245,
#    'goalsAgainst': 527,
#    'goalsDifference': 718,
#    'points': 1318},
#   'away': {'played': 611,
#    'won': 273,
#    'drawn': 159,
#    'lost': 179,
#    'goalsFor': 935,
#    'goalsAgainst': 688,
#    'goalsDifference': 247,
#    'points': 978},
#   'ground': {'name': 'Emirates Stadium',
#    'city': 'London',
#    'capacity': 60272,
#    'location': {'latitude': 51.5548, 'longitude': -0.108533},
#    'source': 'OPTA',
#    'id': 52}},
#  {'team': {'name': 'Liverpool',
#    'club': {'name': 'Liverpool',
#     'shortName': 'Liverpool',
#     'abbr': 'LIV',
#     'id': 10},
#    'teamType': 'FIRST',
#    'shortName': 'Liverpool',
#    'id': 10,
#    'altIds': {'opta': 't14'}},
#   'position': 3,
#   'startingPosition': 3,
#   'overall': {'played': 1221,
#    'won': 649,
#    'drawn': 300,
#    'lost': 272,
#    'goalsFor': 2168,
#    'goalsAgainst': 1224,
#    'goalsDifference': 944,
#    'points': 2247},
#   'home': {'played': 611,
#    'won': 389,
#    'drawn': 145,
#    'lost': 77,
#    'goalsFor': 1245,
#    'goalsAgainst': 489,
#    'goalsDifference': 756,
#    'points': 1312},
#   'away': {'played': 610,
#    'won': 260,
#    'drawn': 155,
#    'lost': 195,
#    'goalsFor': 923,
#    'goalsAgainst': 735,
#    'goalsDifference': 188,
#    'points': 935},
#   'ground': {'name': 'Anfield',
#    'city': 'Liverpool',
#    'capacity': 61276,
#    'location': {'latitude': 53.4313, 'longitude': -2.96158},
#    'source': 'OPTA',
#    'id': 7305}},
#  {'team': {'name': 'Chelsea',
#    'club': {'name': 'Chelsea', 'shortName': 'Chelsea', 'abbr': 'CHE', 'id': 4},
#    'teamType': 'FIRST',
#    'shortName': 'Chelsea',
#    'id': 4,
#    'altIds': {'opta': 't8'}},
#   'position': 4,
#   'startingPosition': 4,
#   'overall': {'played': 1220,
#    'won': 641,
#    'drawn': 303,
#    'lost': 276,
#    'goalsFor': 2066,
#    'goalsAgainst': 1224,
#    'goalsDifference': 842,
#    'points': 2226},
#   'home': {'played': 610,
#    'won': 367,
#    'drawn': 154,
#    'lost': 89,
#    'goalsFor': 1170,
#    'goalsAgainst': 529,
#    'goalsDifference': 641,
#    'points': 1255},
#   'away': {'played': 610,
#    'won': 274,
#    'drawn': 149,
#    'lost': 187,
#    'goalsFor': 896,
#    'goalsAgainst': 695,
#    'goalsDifference': 201,
#    'points': 971},
#   'ground': {'name': 'Stamford Bridge',
#    'city': 'London',
#    'capacity': 41798,
#    'location': {'latitude': 51.4816, 'longitude': -0.191016},
#    'source': 'OPTA',
#    'id': 30}},
#  {'team': {'name': 'Tottenham Hotspur',
#    'club': {'name': 'Tottenham Hotspur',
#     'shortName': 'Spurs',
#     'abbr': 'TOT',
#     'id': 21},
#    'teamType': 'FIRST',
#    'shortName': 'Tottenham Hotspur',
#    'id': 21,
#    'altIds': {'opta': 't6'}},
#   'position': 5,
#   'startingPosition': 5,
#   'overall': {'played': 1221,
#    'won': 538,
#    'drawn': 293,
#    'lost': 390,
#    'goalsFor': 1880,
#    'goalsAgainst': 1546,
#    'goalsDifference': 334,
#    'points': 1907},
#   'home': {'played': 611,
#    'won': 335,
#    'drawn': 133,
#    'lost': 143,
#    'goalsFor': 1066,
#    'goalsAgainst': 664,
#    'goalsDifference': 402,
#    'points': 1138},
#   'away': {'played': 610,
#    'won': 203,
#    'drawn': 160,
#    'lost': 247,
#    'goalsFor': 814,
#    'goalsAgainst': 882,
#    'goalsDifference': -68,
#    'points': 769},
#   'ground': {'name': 'Tottenham Hotspur Stadium',
#    'city': 'London',
#    'capacity': 62850,
#    'source': 'OPTA',
#    'id': 3921}},
#  {'team': {'name': 'Manchester City',
#    'club': {'name': 'Manchester City',
#     'shortName': 'Man City',
#     'abbr': 'MCI',
#     'id': 11},
#    'teamType': 'FIRST',
#    'shortName': 'Man City',
#    'id': 11,
#    'altIds': {'opta': 't43'}},
#   'position': 6,
#   'startingPosition': 6,
#   'overall': {'played': 1031,
#    'won': 522,
#    'drawn': 222,
#    'lost': 287,
#    'goalsFor': 1823,
#    'goalsAgainst': 1132,
#    'goalsDifference': 691,
#    'points': 1788},
#   'home': {'played': 516,
#    'won': 308,
#    'drawn': 103,
#    'lost': 105,
#    'goalsFor': 1055,
#    'goalsAgainst': 488,
#    'goalsDifference': 567,
#    'points': 1027},
#   'away': {'played': 515,
#    'won': 214,
#    'drawn': 119,
#    'lost': 182,
#    'goalsFor': 768,
#    'goalsAgainst': 644,
#    'goalsDifference': 124,
#    'points': 761},
#   'ground': {'name': 'Etihad Stadium',
#    'city': 'Manchester',
#    'capacity': 55000,
#    'location': {'latitude': 53.4832, 'longitude': -2.20042},
#    'source': 'OPTA',
#    'id': 457}},
#  {'team': {'name': 'Everton',
#    'club': {'name': 'Everton', 'shortName': 'Everton', 'abbr': 'EVE', 'id': 7},
#    'teamType': 'FIRST',
#    'shortName': 'Everton',
#    'id': 7,
#    'altIds': {'opta': 't11'}},
#   'position': 7,
#   'startingPosition': 7,
#   'overall': {'played': 1221,
#    'won': 435,
#    'drawn': 340,
#    'lost': 446,
#    'goalsFor': 1557,
#    'goalsAgainst': 1580,
#    'goalsDifference': -23,
#    'points': 1637},
#   'home': {'played': 610,
#    'won': 277,
#    'drawn': 161,
#    'lost': 172,
#    'goalsFor': 913,
#    'goalsAgainst': 685,
#    'goalsDifference': 228,
#    'points': 992},
#   'away': {'played': 611,
#    'won': 158,
#    'drawn': 179,
#    'lost': 274,
#    'goalsFor': 644,
#    'goalsAgainst': 895,
#    'goalsDifference': -251,
#    'points': 653},
#   'annotations': [{'type': 'PD',
#     'description': 'Everton deducted six points and then a further two points, following two separate breaches of the Profitability and Sustainability Rules'}],
#   'ground': {'name': 'Goodison Park',
#    'city': 'Liverpool',
#    'capacity': 39571,
#    'location': {'latitude': 53.4387, 'longitude': -2.96639},
#    'source': 'OPTA',
#    'id': 31}},
#  {'team': {'name': 'Newcastle United',
#    'club': {'name': 'Newcastle United',
#     'shortName': 'Newcastle',
#     'abbr': 'NEW',
#     'id': 23},
#    'teamType': 'FIRST',
#    'shortName': 'Newcastle',
#    'id': 23,
#    'altIds': {'opta': 't4'}},
#   'position': 8,
#   'startingPosition': 8,
#   'overall': {'played': 1103,
#    'won': 415,
#    'drawn': 283,
#    'lost': 405,
#    'goalsFor': 1510,
#    'goalsAgainst': 1502,
#    'goalsDifference': 8,
#    'points': 1528},
#   'home': {'played': 552,
#    'won': 274,
#    'drawn': 137,
#    'lost': 141,
#    'goalsFor': 906,
#    'goalsAgainst': 625,
#    'goalsDifference': 281,
#    'points': 959},
#   'away': {'played': 551,
#    'won': 141,
#    'drawn': 146,
#    'lost': 264,
#    'goalsFor': 604,
#    'goalsAgainst': 877,
#    'goalsDifference': -273,
#    'points': 569},
#   'ground': {'name': "St. James' Park",
#    'city': 'Newcastle',
#    'capacity': 52405,
#    'location': {'latitude': 54.9752, 'longitude': -1.62235},
#    'source': 'OPTA',
#    'id': 27}},
#  {'team': {'name': 'Aston Villa',
#    'club': {'name': 'Aston Villa',
#     'shortName': 'Aston Villa',
#     'abbr': 'AVL',
#     'id': 2},
#    'teamType': 'FIRST',
#    'shortName': 'Aston Villa',
#    'id': 2,
#    'altIds': {'opta': 't7'}},
#   'position': 9,
#   'startingPosition': 9,
#   'overall': {'played': 1108,
#    'won': 390,
#    'drawn': 309,
#    'lost': 409,
#    'goalsFor': 1382,
#    'goalsAgainst': 1448,
#    'goalsDifference': -66,
#    'points': 1479},
#   'home': {'played': 554,
#    'won': 231,
#    'drawn': 155,
#    'lost': 168,
#    'goalsFor': 757,
#    'goalsAgainst': 620,
#    'goalsDifference': 137,
#    'points': 848},
#   'away': {'played': 554,
#    'won': 159,
#    'drawn': 154,
#    'lost': 241,
#    'goalsFor': 625,
#    'goalsAgainst': 828,
#    'goalsDifference': -203,
#    'points': 631},
#   'ground': {'name': 'Villa Park',
#    'city': 'Birmingham',
#    'capacity': 42682,
#    'location': {'latitude': 52.5085, 'longitude': -1.88495},
#    'source': 'OPTA',
#    'id': 43}},
#  {'team': {'name': 'West Ham United',
#    'club': {'name': 'West Ham United',
#     'shortName': 'West Ham',
#     'abbr': 'WHU',
#     'id': 25},
#    'teamType': 'FIRST',
#    'shortName': 'West Ham',
#    'id': 25,
#    'altIds': {'opta': 't21'}},
#   'position': 10,
#   'startingPosition': 10,
#   'overall': {'played': 1066,
#    'won': 359,
#    'drawn': 269,
#    'lost': 438,
#    'goalsFor': 1329,
#    'goalsAgainst': 1540,
#    'goalsDifference': -211,
#    'points': 1346},
#   'home': {'played': 533,
#    'won': 230,
#    'drawn': 135,
#    'lost': 168,
#    'goalsFor': 782,
#    'goalsAgainst': 682,
#    'goalsDifference': 100,
#    'points': 825},
#   'away': {'played': 533,
#    'won': 129,
#    'drawn': 134,
#    'lost': 270,
#    'goalsFor': 547,
#    'goalsAgainst': 858,
#    'goalsDifference': -311,
#    'points': 521},
#   'ground': {'name': 'London Stadium',
#    'city': 'London',
#    'source': 'OPTA',
#    'id': 433}},
#  {'team': {'name': 'Southampton',
#    'club': {'name': 'Southampton',
#     'shortName': 'Southampton',
#     'abbr': 'SOU',
#     'id': 20},
#    'teamType': 'FIRST',
#    'shortName': 'Southampton',
#    'id': 20,
#    'altIds': {'opta': 't20'}},
#   'position': 11,
#   'startingPosition': 11,
#   'overall': {'played': 924,
#    'won': 280,
#    'drawn': 248,
#    'lost': 396,
#    'goalsFor': 1114,
#    'goalsAgainst': 1355,
#    'goalsDifference': -241,
#    'points': 1088},
#   'home': {'played': 462,
#    'won': 180,
#    'drawn': 129,
#    'lost': 153,
#    'goalsFor': 647,
#    'goalsAgainst': 579,
#    'goalsDifference': 68,
#    'points': 669},
#   'away': {'played': 462,
#    'won': 100,
#    'drawn': 119,
#    'lost': 243,
#    'goalsFor': 467,
#    'goalsAgainst': 776,
#    'goalsDifference': -309,
#    'points': 419},
#   'ground': {'name': "St. Mary's Stadium",
#    'city': 'Southampton',
#    'capacity': 32505,
#    'location': {'latitude': 50.9065, 'longitude': -1.39082},
#    'source': 'OPTA',
#    'id': 48}},
#  {'team': {'name': 'Blackburn Rovers',
#    'club': {'name': 'Blackburn Rovers',
#     'shortName': 'Blackburn',
#     'abbr': 'BLB',
#     'id': 3},
#    'teamType': 'FIRST',
#    'shortName': 'Blackburn',
#    'id': 3,
#    'altIds': {'opta': 't5'}},
#   'position': 12,
#   'startingPosition': 12,
#   'overall': {'played': 696,
#    'won': 262,
#    'drawn': 184,
#    'lost': 250,
#    'goalsFor': 927,
#    'goalsAgainst': 907,
#    'goalsDifference': 20,
#    'points': 970},
#   'home': {'played': 348,
#    'won': 169,
#    'drawn': 85,
#    'lost': 94,
#    'goalsFor': 545,
#    'goalsAgainst': 381,
#    'goalsDifference': 164,
#    'points': 592},
#   'away': {'played': 348,
#    'won': 93,
#    'drawn': 99,
#    'lost': 156,
#    'goalsFor': 382,
#    'goalsAgainst': 526,
#    'goalsDifference': -144,
#    'points': 378},
#   'ground': {'name': 'Ewood Park',
#    'city': 'Blackburn',
#    'capacity': 31367,
#    'location': {'latitude': 53.7286, 'longitude': -2.48941},
#    'source': 'OPTA',
#    'id': 5}},
#  {'team': {'name': 'Leicester City',
#    'club': {'name': 'Leicester City',
#     'shortName': 'Leicester',
#     'abbr': 'LEI',
#     'id': 26},
#    'teamType': 'FIRST',
#    'shortName': 'Leicester',
#    'id': 26,
#    'altIds': {'opta': 't13'}},
#   'position': 13,
#   'startingPosition': 13,
#   'overall': {'played': 650,
#    'won': 218,
#    'drawn': 167,
#    'lost': 265,
#    'goalsFor': 871,
#    'goalsAgainst': 936,
#    'goalsDifference': -65,
#    'points': 821},
#   'home': {'played': 325,
#    'won': 130,
#    'drawn': 88,
#    'lost': 107,
#    'goalsFor': 458,
#    'goalsAgainst': 416,
#    'goalsDifference': 42,
#    'points': 478},
#   'away': {'played': 325,
#    'won': 88,
#    'drawn': 79,
#    'lost': 158,
#    'goalsFor': 413,
#    'goalsAgainst': 520,
#    'goalsDifference': -107,
#    'points': 343},
#   'ground': {'name': 'King Power Stadium',
#    'city': 'Leicester',
#    'capacity': 32312,
#    'location': {'latitude': 52.62, 'longitude': -1.1415},
#    'source': 'OPTA',
#    'id': 49}},
#  {'team': {'name': 'Leeds United',
#    'club': {'name': 'Leeds United',
#     'shortName': 'Leeds',
#     'abbr': 'LEE',
#     'id': 9},
#    'teamType': 'FIRST',
#    'shortName': 'Leeds',
#    'id': 9,
#    'altIds': {'opta': 't2'}},
#   'position': 14,
#   'startingPosition': 14,
#   'overall': {'played': 582,
#    'won': 223,
#    'drawn': 151,
#    'lost': 208,
#    'goalsFor': 793,
#    'goalsAgainst': 784,
#    'goalsDifference': 9,
#    'points': 820},
#   'home': {'played': 291,
#    'won': 135,
#    'drawn': 78,
#    'lost': 78,
#    'goalsFor': 430,
#    'goalsAgainst': 327,
#    'goalsDifference': 103,
#    'points': 483},
#   'away': {'played': 291,
#    'won': 88,
#    'drawn': 73,
#    'lost': 130,
#    'goalsFor': 363,
#    'goalsAgainst': 457,
#    'goalsDifference': -94,
#    'points': 337},
#   'ground': {'name': 'Elland Road',
#    'city': 'Leeds',
#    'capacity': 40000,
#    'location': {'latitude': 53.7772, 'longitude': -1.57153},
#    'source': 'OPTA',
#    'id': 205}},
#  {'team': {'name': 'Fulham',
#    'club': {'name': 'Fulham', 'shortName': 'Fulham', 'abbr': 'FUL', 'id': 34},
#    'teamType': 'FIRST',
#    'shortName': 'Fulham',
#    'id': 34,
#    'altIds': {'opta': 't54'}},
#   'position': 15,
#   'startingPosition': 15,
#   'overall': {'played': 640,
#    'won': 188,
#    'drawn': 167,
#    'lost': 285,
#    'goalsFor': 733,
#    'goalsAgainst': 935,
#    'goalsDifference': -202,
#    'points': 731},
#   'home': {'played': 320,
#    'won': 137,
#    'drawn': 69,
#    'lost': 114,
#    'goalsFor': 440,
#    'goalsAgainst': 408,
#    'goalsDifference': 32,
#    'points': 480},
#   'away': {'played': 320,
#    'won': 51,
#    'drawn': 98,
#    'lost': 171,
#    'goalsFor': 293,
#    'goalsAgainst': 527,
#    'goalsDifference': -234,
#    'points': 251},
#   'ground': {'name': 'Craven Cottage',
#    'city': 'London',
#    'capacity': 25700,
#    'location': {'latitude': 51.4745, 'longitude': -0.220993},
#    'source': 'OPTA',
#    'id': 16}},
#  {'team': {'name': 'Middlesbrough',
#    'club': {'name': 'Middlesbrough',
#     'shortName': 'Middlesbrough',
#     'abbr': 'MID',
#     'id': 13},
#    'teamType': 'FIRST',
#    'shortName': 'Boro',
#    'id': 13,
#    'altIds': {'opta': 't25'}},
#   'position': 16,
#   'startingPosition': 16,
#   'overall': {'played': 574,
#    'won': 165,
#    'drawn': 169,
#    'lost': 240,
#    'goalsFor': 648,
#    'goalsAgainst': 794,
#    'goalsDifference': -146,
#    'points': 661},
#   'home': {'played': 287,
#    'won': 110,
#    'drawn': 84,
#    'lost': 93,
#    'goalsFor': 393,
#    'goalsAgainst': 355,
#    'goalsDifference': 38,
#    'points': 414},
#   'away': {'played': 287,
#    'won': 55,
#    'drawn': 85,
#    'lost': 147,
#    'goalsFor': 255,
#    'goalsAgainst': 439,
#    'goalsDifference': -184,
#    'points': 250},
#   'annotations': [{'type': 'PD',
#     'description': 'Middlesbrough deducted 3 points due to late game cancellation'}],
#   'ground': {'name': 'Riverside Stadium',
#    'city': 'Middlesbrough',
#    'location': {'latitude': 54.5781, 'longitude': -1.21776},
#    'source': 'OPTA',
#    'id': 314}},
#  {'team': {'name': 'Crystal Palace',
#    'club': {'name': 'Crystal Palace',
#     'shortName': 'Crystal Palace',
#     'abbr': 'CRY',
#     'id': 6},
#    'teamType': 'FIRST',
#    'shortName': 'Crystal Palace',
#    'id': 6,
#    'altIds': {'opta': 't31'}},
#   'position': 17,
#   'startingPosition': 17,
#   'overall': {'played': 571,
#    'won': 163,
#    'drawn': 150,
#    'lost': 258,
#    'goalsFor': 623,
#    'goalsAgainst': 829,
#    'goalsDifference': -206,
#    'points': 639},
#   'home': {'played': 285,
#    'won': 88,
#    'drawn': 75,
#    'lost': 122,
#    'goalsFor': 313,
#    'goalsAgainst': 370,
#    'goalsDifference': -57,
#    'points': 339},
#   'away': {'played': 286,
#    'won': 75,
#    'drawn': 75,
#    'lost': 136,
#    'goalsFor': 310,
#    'goalsAgainst': 459,
#    'goalsDifference': -149,
#    'points': 300},
#   'ground': {'name': 'Selhurst Park',
#    'city': 'London',
#    'capacity': 25073,
#    'location': {'latitude': 51.3979, 'longitude': -0.085923},
#    'source': 'OPTA',
#    'id': 45}},
#  {'team': {'name': 'Sunderland',
#    'club': {'name': 'Sunderland',
#     'shortName': 'Sunderland',
#     'abbr': 'SUN',
#     'id': 29},
#    'teamType': 'FIRST',
#    'shortName': 'Sunderland',
#    'id': 29,
#    'altIds': {'opta': 't56'}},
#   'position': 18,
#   'startingPosition': 18,
#   'overall': {'played': 608,
#    'won': 153,
#    'drawn': 159,
#    'lost': 296,
#    'goalsFor': 612,
#    'goalsAgainst': 904,
#    'goalsDifference': -292,
#    'points': 618},
#   'home': {'played': 304,
#    'won': 98,
#    'drawn': 87,
#    'lost': 119,
#    'goalsFor': 336,
#    'goalsAgainst': 371,
#    'goalsDifference': -35,
#    'points': 381},
#   'away': {'played': 304,
#    'won': 55,
#    'drawn': 72,
#    'lost': 177,
#    'goalsFor': 276,
#    'goalsAgainst': 533,
#    'goalsDifference': -257,
#    'points': 237},
#   'ground': {'name': 'Stadium of Light',
#    'city': 'Sunderland',
#    'capacity': 48707,
#    'location': {'latitude': 54.9141, 'longitude': -1.3893},
#    'source': 'OPTA',
#    'id': 35}},
#  {'team': {'name': 'Bolton Wanderers',
#    'club': {'name': 'Bolton Wanderers',
#     'shortName': 'Bolton',
#     'abbr': 'BOL',
#     'id': 27},
#    'teamType': 'FIRST',
#    'shortName': 'Bolton',
#    'id': 27,
#    'altIds': {'opta': 't30'}},
#   'position': 19,
#   'startingPosition': 19,
#   'overall': {'played': 494,
#    'won': 149,
#    'drawn': 128,
#    'lost': 217,
#    'goalsFor': 575,
#    'goalsAgainst': 745,
#    'goalsDifference': -170,
#    'points': 575},
#   'home': {'played': 247,
#    'won': 93,
#    'drawn': 75,
#    'lost': 79,
#    'goalsFor': 319,
#    'goalsAgainst': 313,
#    'goalsDifference': 6,
#    'points': 354},
#   'away': {'played': 247,
#    'won': 56,
#    'drawn': 53,
#    'lost': 138,
#    'goalsFor': 256,
#    'goalsAgainst': 432,
#    'goalsDifference': -176,
#    'points': 221},
#   'ground': {'name': 'Toughsheet Community Stadium',
#    'city': 'Bolton',
#    'location': {'latitude': 53.5803, 'longitude': -2.53615},
#    'id': 1799}},
#  {'team': {'name': 'West Bromwich Albion',
#    'club': {'name': 'West Bromwich Albion',
#     'shortName': 'West Brom',
#     'abbr': 'WBA',
#     'id': 36},
#    'teamType': 'FIRST',
#    'shortName': 'West Brom',
#    'id': 36,
#    'altIds': {'opta': 't35'}},
#   'position': 20,
#   'startingPosition': 20,
#   'overall': {'played': 494,
#    'won': 117,
#    'drawn': 139,
#    'lost': 238,
#    'goalsFor': 510,
#    'goalsAgainst': 772,
#    'goalsDifference': -262,
#    'points': 490},
#   'home': {'played': 247,
#    'won': 76,
#    'drawn': 66,
#    'lost': 105,
#    'goalsFor': 295,
#    'goalsAgainst': 361,
#    'goalsDifference': -66,
#    'points': 294},
#   'away': {'played': 247,
#    'won': 41,
#    'drawn': 73,
#    'lost': 133,
#    'goalsFor': 215,
#    'goalsAgainst': 411,
#    'goalsDifference': -196,
#    'points': 196},
#   'ground': {'name': 'The Hawthorns',
#    'city': 'West Bromwich',
#    'capacity': 26445,
#    'location': {'latitude': 52.5099, 'longitude': -1.9638},
#    'source': 'OPTA',
#    'id': 33}},
#  {'team': {'name': 'Stoke City',
#    'club': {'name': 'Stoke City',
#     'shortName': 'Stoke',
#     'abbr': 'STK',
#     'id': 42},
#    'teamType': 'FIRST',
#    'shortName': 'Stoke',
#    'id': 42,
#    'altIds': {'opta': 't110'}},
#   'position': 21,
#   'startingPosition': 21,
#   'overall': {'played': 380,
#    'won': 116,
#    'drawn': 109,
#    'lost': 155,
#    'goalsFor': 398,
#    'goalsAgainst': 525,
#    'goalsDifference': -127,
#    'points': 457},
#   'home': {'played': 190,
#    'won': 81,
#    'drawn': 54,
#    'lost': 55,
#    'goalsFor': 248,
#    'goalsAgainst': 213,
#    'goalsDifference': 35,
#    'points': 297},
#   'away': {'played': 190,
#    'won': 35,
#    'drawn': 55,
#    'lost': 100,
#    'goalsFor': 150,
#    'goalsAgainst': 312,
#    'goalsDifference': -162,
#    'points': 160},
#   'ground': {'name': 'Britannia Stadium',
#    'city': 'Stoke',
#    'capacity': 27740,
#    'location': {'latitude': 52.9886, 'longitude': -2.17469},
#    'source': 'OPTA',
#    'id': 1}},
#  {'team': {'name': 'Wolverhampton Wanderers',
#    'club': {'name': 'Wolverhampton Wanderers',
#     'shortName': 'Wolves',
#     'abbr': 'WOL',
#     'id': 38},
#    'teamType': 'FIRST',
#    'shortName': 'Wolves',
#    'id': 38,
#    'altIds': {'opta': 't39'}},
#   'position': 22,
#   'startingPosition': 22,
#   'overall': {'played': 373,
#    'won': 113,
#    'drawn': 92,
#    'lost': 168,
#    'goalsFor': 403,
#    'goalsAgainst': 569,
#    'goalsDifference': -166,
#    'points': 431},
#   'home': {'played': 186,
#    'won': 71,
#    'drawn': 42,
#    'lost': 73,
#    'goalsFor': 223,
#    'goalsAgainst': 263,
#    'goalsDifference': -40,
#    'points': 255},
#   'away': {'played': 187,
#    'won': 42,
#    'drawn': 50,
#    'lost': 95,
#    'goalsFor': 180,
#    'goalsAgainst': 306,
#    'goalsDifference': -126,
#    'points': 176},
#   'ground': {'name': 'Molineux Stadium',
#    'city': 'Wolverhampton',
#    'capacity': 31500,
#    'location': {'latitude': 52.5904, 'longitude': -2.13077},
#    'source': 'OPTA',
#    'id': 913}},
#  {'team': {'name': 'Coventry City',
#    'club': {'name': 'Coventry City',
#     'shortName': 'Coventry',
#     'abbr': 'COV',
#     'id': 5},
#    'teamType': 'FIRST',
#    'shortName': 'Coventry',
#    'id': 5,
#    'altIds': {'opta': 't9'}},
#   'position': 23,
#   'startingPosition': 23,
#   'overall': {'played': 354,
#    'won': 99,
#    'drawn': 112,
#    'lost': 143,
#    'goalsFor': 387,
#    'goalsAgainst': 490,
#    'goalsDifference': -103,
#    'points': 409},
#   'home': {'played': 177,
#    'won': 65,
#    'drawn': 56,
#    'lost': 56,
#    'goalsFor': 219,
#    'goalsAgainst': 199,
#    'goalsDifference': 20,
#    'points': 251},
#   'away': {'played': 177,
#    'won': 34,
#    'drawn': 56,
#    'lost': 87,
#    'goalsFor': 168,
#    'goalsAgainst': 291,
#    'goalsDifference': -123,
#    'points': 158},
#   'ground': {'name': 'Highfield Road',
#    'city': 'Coventry',
#    'source': 'OPTA',
#    'id': 303}},
#  {'team': {'name': 'Norwich City',
#    'club': {'name': 'Norwich City',
#     'shortName': 'Norwich',
#     'abbr': 'NOR',
#     'id': 14},
#    'teamType': 'FIRST',
#    'shortName': 'Norwich',
#    'id': 14,
#    'altIds': {'opta': 't45'}},
#   'position': 24,
#   'startingPosition': 24,
#   'overall': {'played': 392,
#    'won': 99,
#    'drawn': 105,
#    'lost': 188,
#    'goalsFor': 414,
#    'goalsAgainst': 669,
#    'goalsDifference': -255,
#    'points': 402},
#   'home': {'played': 196,
#    'won': 66,
#    'drawn': 58,
#    'lost': 72,
#    'goalsFor': 240,
#    'goalsAgainst': 279,
#    'goalsDifference': -39,
#    'points': 256},
#   'away': {'played': 196,
#    'won': 33,
#    'drawn': 47,
#    'lost': 116,
#    'goalsFor': 174,
#    'goalsAgainst': 390,
#    'goalsDifference': -216,
#    'points': 146},
#   'ground': {'name': 'Carrow Road',
#    'city': 'Norwich',
#    'capacity': 27244,
#    'location': {'latitude': 52.6224, 'longitude': 1.3086},
#    'source': 'OPTA',
#    'id': 34}},
#  {'team': {'name': 'Sheffield Wednesday',
#    'club': {'name': 'Sheffield Wednesday',
#     'shortName': 'Sheffield Wed',
#     'abbr': 'SHW',
#     'id': 19},
#    'teamType': 'FIRST',
#    'shortName': 'Sheff Weds',
#    'id': 19,
#    'altIds': {'opta': 't19'}},
#   'position': 25,
#   'startingPosition': 25,
#   'overall': {'played': 316,
#    'won': 101,
#    'drawn': 89,
#    'lost': 126,
#    'goalsFor': 409,
#    'goalsAgainst': 453,
#    'goalsDifference': -44,
#    'points': 392},
#   'home': {'played': 158,
#    'won': 63,
#    'drawn': 50,
#    'lost': 45,
#    'goalsFor': 234,
#    'goalsAgainst': 187,
#    'goalsDifference': 47,
#    'points': 239},
#   'away': {'played': 158,
#    'won': 38,
#    'drawn': 39,
#    'lost': 81,
#    'goalsFor': 175,
#    'goalsAgainst': 266,
#    'goalsDifference': -91,
#    'points': 153},
#   'ground': {'name': 'Hillsborough',
#    'city': 'Sheffield',
#    'capacity': 39859,
#    'location': {'latitude': 53.4109, 'longitude': -1.50086},
#    'source': 'OPTA',
#    'id': 60}},
#  {'team': {'name': 'Wimbledon',
#    'club': {'name': 'Wimbledon',
#     'shortName': 'Wimbledon',
#     'abbr': 'WIM',
#     'id': 22},
#    'teamType': 'FIRST',
#    'shortName': 'Wimbledon',
#    'id': 22,
#    'altIds': {'opta': 't1736'}},
#   'position': 26,
#   'startingPosition': 26,
#   'overall': {'played': 316,
#    'won': 99,
#    'drawn': 94,
#    'lost': 123,
#    'goalsFor': 384,
#    'goalsAgainst': 472,
#    'goalsDifference': -88,
#    'points': 391},
#   'home': {'played': 158,
#    'won': 62,
#    'drawn': 46,
#    'lost': 50,
#    'goalsFor': 218,
#    'goalsAgainst': 198,
#    'goalsDifference': 20,
#    'points': 232},
#   'away': {'played': 158,
#    'won': 37,
#    'drawn': 48,
#    'lost': 73,
#    'goalsFor': 166,
#    'goalsAgainst': 274,
#    'goalsDifference': -108,
#    'points': 159},
#   'ground': {'name': 'Selhurst Park',
#    'city': 'London',
#    'capacity': 25073,
#    'location': {'latitude': 51.3979, 'longitude': -0.085923},
#    'source': 'OPTA',
#    'id': 45}},
#  {'team': {'name': 'Charlton Athletic',
#    'club': {'name': 'Charlton Athletic',
#     'shortName': 'Charlton',
#     'abbr': 'CHA',
#     'id': 31},
#    'teamType': 'FIRST',
#    'shortName': 'Charlton',
#    'id': 31,
#    'altIds': {'opta': 't33'}},
#   'position': 27,
#   'startingPosition': 27,
#   'overall': {'played': 304,
#    'won': 93,
#    'drawn': 82,
#    'lost': 129,
#    'goalsFor': 342,
#    'goalsAgainst': 442,
#    'goalsDifference': -100,
#    'points': 361},
#   'home': {'played': 152,
#    'won': 58,
#    'drawn': 40,
#    'lost': 54,
#    'goalsFor': 199,
#    'goalsAgainst': 198,
#    'goalsDifference': 1,
#    'points': 214},
#   'away': {'played': 152,
#    'won': 35,
#    'drawn': 42,
#    'lost': 75,
#    'goalsFor': 143,
#    'goalsAgainst': 244,
#    'goalsDifference': -101,
#    'points': 147},
#   'ground': {'name': 'The Valley',
#    'city': 'London',
#    'capacity': 26875,
#    'location': {'latitude': 51.4865, 'longitude': 0.035877},
#    'source': 'OPTA',
#    'id': 63}},
#  {'team': {'name': 'Burnley',
#    'club': {'name': 'Burnley',
#     'shortName': 'Burnley',
#     'abbr': 'BUR',
#     'id': 43},
#    'teamType': 'FIRST',
#    'shortName': 'Burnley',
#    'id': 43,
#    'altIds': {'opta': 't90'}},
#   'position': 28,
#   'startingPosition': 28,
#   'overall': {'played': 336,
#    'won': 87,
#    'drawn': 83,
#    'lost': 166,
#    'goalsFor': 332,
#    'goalsAgainst': 522,
#    'goalsDifference': -190,
#    'points': 344},
#   'home': {'played': 168,
#    'won': 54,
#    'drawn': 41,
#    'lost': 73,
#    'goalsFor': 177,
#    'goalsAgainst': 231,
#    'goalsDifference': -54,
#    'points': 203},
#   'away': {'played': 168,
#    'won': 33,
#    'drawn': 42,
#    'lost': 93,
#    'goalsFor': 155,
#    'goalsAgainst': 291,
#    'goalsDifference': -136,
#    'points': 141},
#   'ground': {'name': 'Turf Moor',
#    'city': 'Burnley',
#    'capacity': 21401,
#    'location': {'latitude': 53.7885, 'longitude': -2.23149},
#    'source': 'OPTA',
#    'id': 47}},
#  {'team': {'name': 'Wigan Athletic',
#    'club': {'name': 'Wigan Athletic',
#     'shortName': 'Wigan',
#     'abbr': 'WIG',
#     'id': 39},
#    'teamType': 'FIRST',
#    'shortName': 'Wigan',
#    'id': 39,
#    'altIds': {'opta': 't111'}},
#   'position': 29,
#   'startingPosition': 29,
#   'overall': {'played': 304,
#    'won': 85,
#    'drawn': 76,
#    'lost': 143,
#    'goalsFor': 316,
#    'goalsAgainst': 482,
#    'goalsDifference': -166,
#    'points': 331},
#   'home': {'played': 152,
#    'won': 48,
#    'drawn': 45,
#    'lost': 59,
#    'goalsFor': 169,
#    'goalsAgainst': 215,
#    'goalsDifference': -46,
#    'points': 189},
#   'away': {'played': 152,
#    'won': 37,
#    'drawn': 31,
#    'lost': 84,
#    'goalsFor': 147,
#    'goalsAgainst': 267,
#    'goalsDifference': -120,
#    'points': 142},
#   'ground': {'name': 'DW Stadium',
#    'city': 'Wigan',
#    'capacity': 25138,
#    'location': {'latitude': 53.5472, 'longitude': -2.65452},
#    'source': 'OPTA',
#    'id': 2}},
#  {'team': {'name': 'Brighton & Hove Albion',
#    'club': {'name': 'Brighton and Hove Albion',
#     'shortName': 'Brighton',
#     'abbr': 'BHA',
#     'id': 131},
#    'teamType': 'FIRST',
#    'shortName': 'Brighton',
#    'id': 131,
#    'altIds': {'opta': 't36'}},
#   'position': 30,
#   'startingPosition': 30,
#   'overall': {'played': 259,
#    'won': 77,
#    'drawn': 83,
#    'lost': 99,
#    'goalsFor': 313,
#    'goalsAgainst': 360,
#    'goalsDifference': -47,
#    'points': 314},
#   'home': {'played': 129,
#    'won': 44,
#    'drawn': 46,
#    'lost': 39,
#    'goalsFor': 169,
#    'goalsAgainst': 165,
#    'goalsDifference': 4,
#    'points': 178},
#   'away': {'played': 130,
#    'won': 33,
#    'drawn': 37,
#    'lost': 60,
#    'goalsFor': 144,
#    'goalsAgainst': 195,
#    'goalsDifference': -51,
#    'points': 136},
#   'ground': {'name': 'American Express Stadium',
#    'city': 'Falmer',
#    'capacity': 30750,
#    'location': {'latitude': 50.8606, 'longitude': -0.082237},
#    'source': 'OPTA',
#    'id': 7306}},
#  {'team': {'name': 'Swansea City',
#    'club': {'name': 'Swansea City',
#     'shortName': 'Swansea',
#     'abbr': 'SWA',
#     'id': 45},
#    'teamType': 'FIRST',
#    'shortName': 'Swansea',
#    'id': 45,
#    'altIds': {'opta': 't80'}},
#   'position': 31,
#   'startingPosition': 31,
#   'overall': {'played': 266,
#    'won': 82,
#    'drawn': 66,
#    'lost': 118,
#    'goalsFor': 306,
#    'goalsAgainst': 383,
#    'goalsDifference': -77,
#    'points': 312},
#   'home': {'played': 133,
#    'won': 51,
#    'drawn': 37,
#    'lost': 45,
#    'goalsFor': 179,
#    'goalsAgainst': 170,
#    'goalsDifference': 9,
#    'points': 190},
#   'away': {'played': 133,
#    'won': 31,
#    'drawn': 29,
#    'lost': 73,
#    'goalsFor': 127,
#    'goalsAgainst': 213,
#    'goalsDifference': -86,
#    'points': 122},
#   'ground': {'name': 'Liberty Stadium',
#    'city': 'Swansea',
#    'capacity': 21028,
#    'location': {'latitude': 51.6422, 'longitude': -3.93512},
#    'source': 'OPTA',
#    'id': 86}},
#  {'team': {'name': 'Queens Park Rangers',
#    'club': {'name': 'Queens Park Rangers',
#     'shortName': 'QPR',
#     'abbr': 'QPR',
#     'id': 17},
#    'teamType': 'FIRST',
#    'shortName': 'QPR',
#    'id': 17,
#    'altIds': {'opta': 't52'}},
#   'position': 32,
#   'startingPosition': 32,
#   'overall': {'played': 278,
#    'won': 81,
#    'drawn': 65,
#    'lost': 132,
#    'goalsFor': 339,
#    'goalsAgainst': 431,
#    'goalsDifference': -92,
#    'points': 308},
#   'home': {'played': 139,
#    'won': 51,
#    'drawn': 38,
#    'lost': 50,
#    'goalsFor': 194,
#    'goalsAgainst': 190,
#    'goalsDifference': 4,
#    'points': 191},
#   'away': {'played': 139,
#    'won': 30,
#    'drawn': 27,
#    'lost': 82,
#    'goalsFor': 145,
#    'goalsAgainst': 241,
#    'goalsDifference': -96,
#    'points': 117},
#   'ground': {'name': 'MATRADE Loftus Road Stadium',
#    'city': 'London',
#    'capacity': 18000,
#    'location': {'latitude': 51.5097, 'longitude': -0.232037},
#    'source': 'OPTA',
#    'id': 3981}},
#  {'team': {'name': 'Nottingham Forest',
#    'club': {'name': 'Nottingham Forest',
#     'shortName': "Nott'm Forest",
#     'abbr': 'NFO',
#     'id': 15},
#    'teamType': 'FIRST',
#    'shortName': "Nott'm Forest",
#    'id': 15,
#    'altIds': {'opta': 't17'}},
#   'position': 33,
#   'startingPosition': 33,
#   'overall': {'played': 268,
#    'won': 76,
#    'drawn': 78,
#    'lost': 114,
#    'goalsFor': 307,
#    'goalsAgainst': 411,
#    'goalsDifference': -104,
#    'points': 302},
#   'home': {'played': 134,
#    'won': 48,
#    'drawn': 42,
#    'lost': 44,
#    'goalsFor': 165,
#    'goalsAgainst': 165,
#    'goalsDifference': 0,
#    'points': 186},
#   'away': {'played': 134,
#    'won': 28,
#    'drawn': 36,
#    'lost': 70,
#    'goalsFor': 142,
#    'goalsAgainst': 246,
#    'goalsDifference': -104,
#    'points': 120},
#   'annotations': [{'type': 'PD',
#     'description': 'Nottingham Forest deducted four points following a breach of the Premier League’s Profitability and Sustainability Rules. That decision is currently under appeal'}],
#   'ground': {'name': 'The City Ground',
#    'city': 'Nottingham',
#    'capacity': 30602,
#    'location': {'latitude': 52.9396, 'longitude': -1.13258},
#    'source': 'OPTA',
#    'id': 2548}},
#  {'team': {'name': 'Birmingham City',
#    'club': {'name': 'Birmingham City',
#     'shortName': 'Birmingham',
#     'abbr': 'BIR',
#     'id': 35},
#    'teamType': 'FIRST',
#    'shortName': 'Birmingham',
#    'id': 35,
#    'altIds': {'opta': 't41'}},
#   'position': 34,
#   'startingPosition': 34,
#   'overall': {'played': 266,
#    'won': 73,
#    'drawn': 82,
#    'lost': 111,
#    'goalsFor': 273,
#    'goalsAgainst': 360,
#    'goalsDifference': -87,
#    'points': 301},
#   'home': {'played': 133,
#    'won': 50,
#    'drawn': 46,
#    'lost': 37,
#    'goalsFor': 162,
#    'goalsAgainst': 140,
#    'goalsDifference': 22,
#    'points': 196},
#   'away': {'played': 133,
#    'won': 23,
#    'drawn': 36,
#    'lost': 74,
#    'goalsFor': 111,
#    'goalsAgainst': 220,
#    'goalsDifference': -109,
#    'points': 105},
#   'ground': {'name': "St. Andrew's Trillion Trophy Stadium",
#    'city': 'Birmingham',
#    'location': {'latitude': 52.4756, 'longitude': -1.86824},
#    'id': 1739}},
#  {'team': {'name': 'Portsmouth',
#    'club': {'name': 'Portsmouth',
#     'shortName': 'Portsmouth',
#     'abbr': 'POR',
#     'id': 37},
#    'teamType': 'FIRST',
#    'shortName': 'Portsmouth',
#    'id': 37,
#    'altIds': {'opta': 't47'}},
#   'position': 35,
#   'startingPosition': 35,
#   'overall': {'played': 266,
#    'won': 79,
#    'drawn': 65,
#    'lost': 122,
#    'goalsFor': 292,
#    'goalsAgainst': 380,
#    'goalsDifference': -88,
#    'points': 293},
#   'home': {'played': 133,
#    'won': 54,
#    'drawn': 34,
#    'lost': 45,
#    'goalsFor': 184,
#    'goalsAgainst': 159,
#    'goalsDifference': 25,
#    'points': 196},
#   'away': {'played': 133,
#    'won': 25,
#    'drawn': 31,
#    'lost': 77,
#    'goalsFor': 108,
#    'goalsAgainst': 221,
#    'goalsDifference': -113,
#    'points': 106},
#   'annotations': [{'type': 'PD',
#     'description': 'Portsmouth deducted 9 points following administration'}],
#   'ground': {'name': 'Fratton Park',
#    'city': 'Portsmouth',
#    'capacity': 20224,
#    'location': {'latitude': 50.7959, 'longitude': -1.06368},
#    'source': 'OPTA',
#    'id': 70}},
#  {'team': {'name': 'Bournemouth',
#    'club': {'name': 'Bournemouth',
#     'shortName': 'Bournemouth',
#     'abbr': 'BOU',
#     'id': 127},
#    'teamType': 'FIRST',
#    'shortName': 'Bournemouth',
#    'id': 127,
#    'altIds': {'opta': 't91'}},
#   'position': 36,
#   'startingPosition': 36,
#   'overall': {'played': 259,
#    'won': 78,
#    'drawn': 57,
#    'lost': 124,
#    'goalsFor': 323,
#    'goalsAgainst': 456,
#    'goalsDifference': -133,
#    'points': 291},
#   'home': {'played': 130,
#    'won': 46,
#    'drawn': 34,
#    'lost': 50,
#    'goalsFor': 177,
#    'goalsAgainst': 200,
#    'goalsDifference': -23,
#    'points': 172},
#   'away': {'played': 129,
#    'won': 32,
#    'drawn': 23,
#    'lost': 74,
#    'goalsFor': 146,
#    'goalsAgainst': 256,
#    'goalsDifference': -110,
#    'points': 119},
#   'ground': {'name': 'Vitality Stadium',
#    'city': 'Bournemouth',
#    'capacity': 11464,
#    'location': {'latitude': 50.7349, 'longitude': -1.83899},
#    'source': 'OPTA',
#    'id': 914}},
#  {'team': {'name': 'Watford',
#    'club': {'name': 'Watford',
#     'shortName': 'Watford',
#     'abbr': 'WAT',
#     'id': 33},
#    'teamType': 'FIRST',
#    'shortName': 'Watford',
#    'id': 33,
#    'altIds': {'opta': 't57'}},
#   'position': 37,
#   'startingPosition': 37,
#   'overall': {'played': 304,
#    'won': 73,
#    'drawn': 66,
#    'lost': 165,
#    'goalsFor': 310,
#    'goalsAgainst': 518,
#    'goalsDifference': -208,
#    'points': 285},
#   'home': {'played': 152,
#    'won': 45,
#    'drawn': 40,
#    'lost': 67,
#    'goalsFor': 180,
#    'goalsAgainst': 236,
#    'goalsDifference': -56,
#    'points': 175},
#   'away': {'played': 152,
#    'won': 28,
#    'drawn': 26,
#    'lost': 98,
#    'goalsFor': 130,
#    'goalsAgainst': 282,
#    'goalsDifference': -152,
#    'points': 110},
#   'ground': {'name': 'Vicarage Road',
#    'city': 'Watford',
#    'capacity': 22000,
#    'location': {'latitude': 51.6496, 'longitude': -0.401731},
#    'source': 'OPTA',
#    'id': 136}},
#  {'team': {'name': 'Derby County',
#    'club': {'name': 'Derby County',
#     'shortName': 'Derby',
#     'abbr': 'DER',
#     'id': 28},
#    'teamType': 'FIRST',
#    'shortName': 'Derby',
#    'id': 28,
#    'altIds': {'opta': 't24'}},
#   'position': 38,
#   'startingPosition': 38,
#   'overall': {'played': 266,
#    'won': 68,
#    'drawn': 70,
#    'lost': 128,
#    'goalsFor': 271,
#    'goalsAgainst': 420,
#    'goalsDifference': -149,
#    'points': 274},
#   'home': {'played': 133,
#    'won': 48,
#    'drawn': 35,
#    'lost': 50,
#    'goalsFor': 157,
#    'goalsAgainst': 177,
#    'goalsDifference': -20,
#    'points': 179},
#   'away': {'played': 133,
#    'won': 20,
#    'drawn': 35,
#    'lost': 78,
#    'goalsFor': 114,
#    'goalsAgainst': 243,
#    'goalsDifference': -129,
#    'points': 95},
#   'ground': {'name': 'Pride Park Stadium',
#    'city': 'Derby',
#    'location': {'latitude': 52.9146, 'longitude': -1.44802},
#    'source': 'OPTA',
#    'id': 929}},
#  {'team': {'name': 'Sheffield United',
#    'club': {'name': 'Sheffield United',
#     'shortName': 'Sheffield Utd',
#     'abbr': 'SHU',
#     'id': 18},
#    'teamType': 'FIRST',
#    'shortName': 'Sheffield Utd',
#    'id': 18,
#    'altIds': {'opta': 't49'}},
#   'position': 39,
#   'startingPosition': 40,
#   'overall': {'played': 229,
#    'won': 56,
#    'drawn': 57,
#    'lost': 116,
#    'goalsFor': 217,
#    'goalsAgainst': 352,
#    'goalsDifference': -135,
#    'points': 225},
#   'home': {'played': 115,
#    'won': 40,
#    'drawn': 30,
#    'lost': 45,
#    'goalsFor': 134,
#    'goalsAgainst': 152,
#    'goalsDifference': -18,
#    'points': 150},
#   'away': {'played': 114,
#    'won': 16,
#    'drawn': 27,
#    'lost': 71,
#    'goalsFor': 83,
#    'goalsAgainst': 200,
#    'goalsDifference': -117,
#    'points': 75},
#   'ground': {'name': 'Bramall Lane',
#    'city': 'Sheffield',
#    'capacity': 30370,
#    'location': {'latitude': 53.3699, 'longitude': -1.47067},
#    'source': 'OPTA',
#    'id': 206}},
#  {'team': {'name': 'Ipswich Town',
#    'club': {'name': 'Ipswich Town',
#     'shortName': 'Ipswich',
#     'abbr': 'IPS',
#     'id': 8},
#    'teamType': 'FIRST',
#    'shortName': 'Ipswich',
#    'id': 8,
#    'altIds': {'opta': 't40'}},
#   'position': 40,
#   'startingPosition': 39,
#   'overall': {'played': 202,
#    'won': 57,
#    'drawn': 53,
#    'lost': 92,
#    'goalsFor': 219,
#    'goalsAgainst': 312,
#    'goalsDifference': -93,
#    'points': 224},
#   'home': {'played': 101,
#    'won': 35,
#    'drawn': 29,
#    'lost': 37,
#    'goalsFor': 125,
#    'goalsAgainst': 127,
#    'goalsDifference': -2,
#    'points': 134},
#   'away': {'played': 101,
#    'won': 22,
#    'drawn': 24,
#    'lost': 55,
#    'goalsFor': 94,
#    'goalsAgainst': 185,
#    'goalsDifference': -91,
#    'points': 90},
#   'ground': {'name': 'Portman Road',
#    'city': 'Ipswich',
#    'capacity': 30300,
#    'location': {'latitude': 52.0542, 'longitude': 1.14471},
#    'source': 'OPTA',
#    'id': 66}},
#  {'team': {'name': 'Hull City',
#    'club': {'name': 'Hull City', 'shortName': 'Hull', 'abbr': 'HUL', 'id': 41},
#    'teamType': 'FIRST',
#    'shortName': 'Hull',
#    'id': 41,
#    'altIds': {'opta': 't88'}},
#   'position': 41,
#   'startingPosition': 41,
#   'overall': {'played': 190,
#    'won': 41,
#    'drawn': 48,
#    'lost': 101,
#    'goalsFor': 181,
#    'goalsAgainst': 323,
#    'goalsDifference': -142,
#    'points': 171},
#   'home': {'played': 95,
#    'won': 29,
#    'drawn': 24,
#    'lost': 42,
#    'goalsFor': 107,
#    'goalsAgainst': 145,
#    'goalsDifference': -38,
#    'points': 111},
#   'away': {'played': 95,
#    'won': 12,
#    'drawn': 24,
#    'lost': 59,
#    'goalsFor': 74,
#    'goalsAgainst': 178,
#    'goalsDifference': -104,
#    'points': 60},
#   'ground': {'name': 'KCOM Stadium',
#    'city': 'Hull',
#    'capacity': 25400,
#    'location': {'latitude': 53.746, 'longitude': -0.367677},
#    'source': 'OPTA',
#    'id': 441}},
#  {'team': {'name': 'Brentford',
#    'club': {'name': 'Brentford',
#     'shortName': 'Brentford',
#     'abbr': 'BRE',
#     'id': 130},
#    'teamType': 'FIRST',
#    'shortName': 'Brentford',
#    'id': 130,
#    'altIds': {'opta': 't94'}},
#   'position': 42,
#   'startingPosition': 42,
#   'overall': {'played': 108,
#    'won': 35,
#    'drawn': 29,
#    'lost': 44,
#    'goalsFor': 151,
#    'goalsAgainst': 160,
#    'goalsDifference': -9,
#    'points': 134},
#   'home': {'played': 54,
#    'won': 21,
#    'drawn': 16,
#    'lost': 17,
#    'goalsFor': 82,
#    'goalsAgainst': 69,
#    'goalsDifference': 13,
#    'points': 79},
#   'away': {'played': 54,
#    'won': 14,
#    'drawn': 13,
#    'lost': 27,
#    'goalsFor': 69,
#    'goalsAgainst': 91,
#    'goalsDifference': -22,
#    'points': 55},
#   'ground': {'name': 'Gtech Community Stadium',
#    'city': 'Brentford',
#    'capacity': 17250,
#    'source': 'OPTA',
#    'id': 4003}},
#  {'team': {'name': 'Reading',
#    'club': {'name': 'Reading',
#     'shortName': 'Reading',
#     'abbr': 'RDG',
#     'id': 40},
#    'teamType': 'FIRST',
#    'shortName': 'Reading',
#    'id': 40,
#    'altIds': {'opta': 't108'}},
#   'position': 43,
#   'startingPosition': 43,
#   'overall': {'played': 114,
#    'won': 32,
#    'drawn': 23,
#    'lost': 59,
#    'goalsFor': 136,
#    'goalsAgainst': 186,
#    'goalsDifference': -50,
#    'points': 119},
#   'home': {'played': 57,
#    'won': 23,
#    'drawn': 12,
#    'lost': 22,
#    'goalsFor': 71,
#    'goalsAgainst': 78,
#    'goalsDifference': -7,
#    'points': 81},
#   'away': {'played': 57,
#    'won': 9,
#    'drawn': 11,
#    'lost': 37,
#    'goalsFor': 65,
#    'goalsAgainst': 108,
#    'goalsDifference': -43,
#    'points': 38},
#   'ground': {'name': 'Madejski Stadium',
#    'city': 'Reading',
#    'capacity': 24161,
#    'location': {'latitude': 51.4223, 'longitude': -0.983497},
#    'source': 'OPTA',
#    'id': 24}},
#  {'team': {'name': 'Oldham Athletic',
#    'club': {'name': 'Oldham Athletic',
#     'shortName': 'Oldham',
#     'abbr': 'OLD',
#     'id': 16},
#    'teamType': 'FIRST',
#    'shortName': 'Oldham',
#    'id': 16,
#    'altIds': {'opta': 't105'}},
#   'position': 44,
#   'startingPosition': 44,
#   'overall': {'played': 84,
#    'won': 22,
#    'drawn': 23,
#    'lost': 39,
#    'goalsFor': 105,
#    'goalsAgainst': 142,
#    'goalsDifference': -37,
#    'points': 89},
#   'home': {'played': 42,
#    'won': 15,
#    'drawn': 14,
#    'lost': 13,
#    'goalsFor': 67,
#    'goalsAgainst': 63,
#    'goalsDifference': 4,
#    'points': 59},
#   'away': {'played': 42,
#    'won': 7,
#    'drawn': 9,
#    'lost': 26,
#    'goalsFor': 38,
#    'goalsAgainst': 79,
#    'goalsDifference': -41,
#    'points': 30},
#   'ground': {'name': 'Boundary Park',
#    'city': 'Oldham',
#    'capacity': 13559,
#    'location': {'latitude': 53.5546, 'longitude': -1.1361},
#    'source': 'OPTA',
#    'id': 83}},
#  {'team': {'name': 'Cardiff City',
#    'club': {'name': 'Cardiff City',
#     'shortName': 'Cardiff',
#     'abbr': 'CAR',
#     'id': 46},
#    'teamType': 'FIRST',
#    'shortName': 'Cardiff',
#    'id': 46,
#    'altIds': {'opta': 't97'}},
#   'position': 45,
#   'startingPosition': 45,
#   'overall': {'played': 76,
#    'won': 17,
#    'drawn': 13,
#    'lost': 46,
#    'goalsFor': 66,
#    'goalsAgainst': 143,
#    'goalsDifference': -77,
#    'points': 64},
#   'home': {'played': 38,
#    'won': 11,
#    'drawn': 7,
#    'lost': 20,
#    'goalsFor': 41,
#    'goalsAgainst': 73,
#    'goalsDifference': -32,
#    'points': 40},
#   'away': {'played': 38,
#    'won': 6,
#    'drawn': 6,
#    'lost': 26,
#    'goalsFor': 25,
#    'goalsAgainst': 70,
#    'goalsDifference': -45,
#    'points': 24},
#   'ground': {'name': 'Cardiff City Stadium',
#    'city': 'Cardiff',
#    'capacity': 26896,
#    'location': {'latitude': 51.4745, 'longitude': -3.19981},
#    'source': 'OPTA',
#    'id': 41}},
#  {'team': {'name': 'Bradford City',
#    'club': {'name': 'Bradford City',
#     'shortName': 'Bradford',
#     'abbr': 'BRA',
#     'id': 32},
#    'teamType': 'FIRST',
#    'shortName': 'Bradford',
#    'id': 32,
#    'altIds': {'opta': 't55'}},
#   'position': 46,
#   'startingPosition': 46,
#   'overall': {'played': 76,
#    'won': 14,
#    'drawn': 20,
#    'lost': 42,
#    'goalsFor': 68,
#    'goalsAgainst': 138,
#    'goalsDifference': -70,
#    'points': 62},
#   'home': {'played': 38,
#    'won': 10,
#    'drawn': 15,
#    'lost': 13,
#    'goalsFor': 46,
#    'goalsAgainst': 58,
#    'goalsDifference': -12,
#    'points': 45},
#   'away': {'played': 38,
#    'won': 4,
#    'drawn': 5,
#    'lost': 29,
#    'goalsFor': 22,
#    'goalsAgainst': 80,
#    'goalsDifference': -58,
#    'points': 17},
#   'ground': {'name': 'Valley Parade',
#    'city': 'Bradford',
#    'capacity': 24000,
#    'location': {'latitude': 53.8038, 'longitude': -1.75949},
#    'source': 'OPTA',
#    'id': 208}},
#  {'team': {'name': 'Huddersfield Town',
#    'club': {'name': 'Huddersfield Town',
#     'shortName': 'Huddersfield',
#     'abbr': 'HUD',
#     'id': 159},
#    'teamType': 'FIRST',
#    'shortName': 'Huddersfield',
#    'id': 159,
#    'altIds': {'opta': 't38'}},
#   'position': 47,
#   'startingPosition': 47,
#   'overall': {'played': 76,
#    'won': 12,
#    'drawn': 17,
#    'lost': 47,
#    'goalsFor': 50,
#    'goalsAgainst': 134,
#    'goalsDifference': -84,
#    'points': 53},
#   'home': {'played': 38,
#    'won': 8,
#    'drawn': 8,
#    'lost': 22,
#    'goalsFor': 26,
#    'goalsAgainst': 56,
#    'goalsDifference': -30,
#    'points': 32},
#   'away': {'played': 38,
#    'won': 4,
#    'drawn': 9,
#    'lost': 25,
#    'goalsFor': 24,
#    'goalsAgainst': 78,
#    'goalsDifference': -54,
#    'points': 21},
#   'ground': {'name': "John Smith's Stadium",
#    'city': 'Huddersfield',
#    'capacity': 24500,
#    'location': {'latitude': 53.6539, 'longitude': -1.76906},
#    'source': 'OPTA',
#    'id': 65}},
#  {'team': {'name': 'Blackpool',
#    'club': {'name': 'Blackpool',
#     'shortName': 'Blackpool',
#     'abbr': 'BLP',
#     'id': 44},
#    'teamType': 'FIRST',
#    'shortName': 'Blackpool',
#    'id': 44,
#    'altIds': {'opta': 't92'}},
#   'position': 48,
#   'startingPosition': 48,
#   'overall': {'played': 38,
#    'won': 10,
#    'drawn': 9,
#    'lost': 19,
#    'goalsFor': 55,
#    'goalsAgainst': 78,
#    'goalsDifference': -23,
#    'points': 39},
#   'home': {'played': 19,
#    'won': 5,
#    'drawn': 5,
#    'lost': 9,
#    'goalsFor': 30,
#    'goalsAgainst': 37,
#    'goalsDifference': -7,
#    'points': 20},
#   'away': {'played': 19,
#    'won': 5,
#    'drawn': 4,
#    'lost': 10,
#    'goalsFor': 25,
#    'goalsAgainst': 41,
#    'goalsDifference': -16,
#    'points': 19},
#   'ground': {'name': 'Bloomfield Road',
#    'city': 'Blackpool',
#    'capacity': 16220,
#    'location': {'latitude': 53.8296, 'longitude': -3.05569},
#    'source': 'OPTA',
#    'id': 210}},
#  {'team': {'name': 'Barnsley',
#    'club': {'name': 'Barnsley',
#     'shortName': 'Barnsley',
#     'abbr': 'BAR',
#     'id': 30},
#    'teamType': 'FIRST',
#    'shortName': 'Barnsley',
#    'id': 30,
#    'altIds': {'opta': 't37'}},
#   'position': 49,
#   'startingPosition': 49,
#   'overall': {'played': 38,
#    'won': 10,
#    'drawn': 5,
#    'lost': 23,
#    'goalsFor': 37,
#    'goalsAgainst': 82,
#    'goalsDifference': -45,
#    'points': 35},
#   'home': {'played': 19,
#    'won': 7,
#    'drawn': 4,
#    'lost': 8,
#    'goalsFor': 25,
#    'goalsAgainst': 35,
#    'goalsDifference': -10,
#    'points': 25},
#   'away': {'played': 19,
#    'won': 3,
#    'drawn': 1,
#    'lost': 15,
#    'goalsFor': 12,
#    'goalsAgainst': 47,
#    'goalsDifference': -35,
#    'points': 10},
#   'ground': {'name': 'Oakwell',
#    'city': 'Barnsley',
#    'capacity': 23009,
#    'location': {'latitude': 53.5523, 'longitude': -1.46863},
#    'source': 'OPTA',
#    'id': 64}},
#  {'team': {'name': 'Swindon Town',
#    'club': {'name': 'Swindon Town',
#     'shortName': 'Swindon',
#     'abbr': 'SWI',
#     'id': 24},
#    'teamType': 'FIRST',
#    'shortName': 'Swindon',
#    'id': 24,
#    'altIds': {'opta': 't46'}},
#   'position': 50,
#   'startingPosition': 50,
#   'overall': {'played': 42,
#    'won': 5,
#    'drawn': 15,
#    'lost': 22,
#    'goalsFor': 47,
#    'goalsAgainst': 100,
#    'goalsDifference': -53,
#    'points': 30},
#   'home': {'played': 21,
#    'won': 4,
#    'drawn': 7,
#    'lost': 10,
#    'goalsFor': 25,
#    'goalsAgainst': 45,
#    'goalsDifference': -20,
#    'points': 19},
#   'away': {'played': 21,
#    'won': 1,
#    'drawn': 8,
#    'lost': 12,
#    'goalsFor': 22,
#    'goalsAgainst': 55,
#    'goalsDifference': -33,
#    'points': 11},
#   'ground': {'name': 'County Ground',
#    'city': 'Swindon',
#    'capacity': 15728,
#    'location': {'latitude': 51.5644, 'longitude': -1.77152},
#    'source': 'OPTA',
#    'id': 69}},
#  {'team': {'name': 'Luton Town',
#    'club': {'name': 'Luton Town',
#     'shortName': 'Luton',
#     'abbr': 'LUT',
#     'id': 163},
#    'teamType': 'FIRST',
#    'shortName': 'Luton',
#    'id': 163,
#    'altIds': {'opta': 't102'}},
#   'position': 51,
#   'startingPosition': 51,
#   'overall': {'played': 32,
#    'won': 6,
#    'drawn': 7,
#    'lost': 19,
#    'goalsFor': 45,
#    'goalsAgainst': 65,
#    'goalsDifference': -20,
#    'points': 25},
#   'home': {'played': 16,
#    'won': 4,
#    'drawn': 3,
#    'lost': 9,
#    'goalsFor': 24,
#    'goalsAgainst': 27,
#    'goalsDifference': -3,
#    'points': 15},
#   'away': {'played': 16,
#    'won': 2,
#    'drawn': 4,
#    'lost': 10,
#    'goalsFor': 21,
#    'goalsAgainst': 38,
#    'goalsDifference': -17,
#    'points': 10},
#   'ground': {'name': 'Kenilworth Road',
#    'city': 'Luton',
#    'capacity': 9975,
#    'source': 'OPTA',
#    'id': 2025}}]

# %%
def parse_ClubData(data):
    clubs_data = []
    for clubs in data:
        try:
            new_club = ClubData(
                name= clubs['team']['name'],
                position= clubs['position'],
                stadium= clubs['ground']['name'],
                capacity= clubs['ground'].get('capacity', None),
                city= clubs['ground']['city'],
                #home_data
                home_played= clubs['home']['played'],
                home_won= clubs['home']['won'],
                home_drawn= clubs['home']['drawn'],
                home_lost= clubs['home']['lost'],
                home_goalsFor= clubs['home']['goalsFor'],
                home_goalsAgainst= clubs['home']['goalsAgainst'],
                home_points= clubs['home']['points'],

                #away_data
                away_played= clubs['away']['played'],
                away_won= clubs['away']['won'],
                away_drawn= clubs['away']['drawn'],
                away_lost= clubs['away']['lost'],
                away_goalsFor= clubs['away']['goalsFor'],
                away_goalsAgainst= clubs['away']['goalsAgainst'],
                away_points= clubs['away']['points'],

                #overall_data
                played= clubs['overall']['played'],
                won= clubs['overall']['won'],
                drawn= clubs['overall']['drawn'],
                lost= clubs['overall']['lost'],
                goalsFor= clubs['overall']['goalsFor'],
                goalsAgainst= clubs['overall']['goalsAgainst'],
                points= clubs['overall']['points']
            )
            clubs_data.append(asdict(new_club))
        except:
            print(f"Skipping entry due to missing key: {e}")
    return clubs_data

# %%
def get_ClubStats(data):
    club_stats = []
    for club in data:
        id = club['team']['id']
        print(id)
        # clubIDs.append(id)
        querystring = {
        "altIds": "true",
        "detail": "1",
        "FOOTBALL_COMPETITION": "1",
        "comps": "1"
        }
        headers = {
        "accept": "*/*",
        "accept-language": "en-US,en;q=0.9",
        "content-type": "application/x-www-form-urlencoded; charset=UTF-8",
        "^if-none-match": "W/^0fd4c028efcbfea9a8933c1f4030985fc^^",
        "origin": "https://www.premierleague.com",
        "referer": "https://www.premierleague.com/",
        "^sec-ch-ua": "^Microsoft",
        "sec-ch-ua-mobile": "?0",
        "^sec-ch-ua-platform": "^Windows^^",
        "sec-fetch-dest": "empty",
        "sec-fetch-mode": "cors",
        "sec-fetch-site": "cross-site",
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36 Edg/123.0.0.0"
        }
        url = f"https://footballapi.pulselive.com/football/stats/team/{id}"
        try:
            response = httpx.get(url, headers=headers, params=querystring, timeout= 10)
            stats_json = response.json()['stats']
            if stats_json:
                club_stats.append(stats_json)
        except httpx.TimeoutException:
            print("Request timed out.")
    return club_stats

# %%
def parse_ClubStats(data):
    club_stats = []
    for clubs in data:
        try:
            new_club = ClubStats(
                cleanSheets=int(next((item['value'] for item in clubs if item['name'] == 'clean_sheet'), 0)),
                ownGoals=int(next((item['value'] for item in clubs if item['name'] == 'own_goals'), 0)),
                yellowCards=int(next((item['value'] for item in clubs if item['name'] == 'total_yel_card'), 0)),
                redCards=int(next((item['value'] for item in clubs if item['name'] == 'total_red_card'), 0)),
                fouls=int(next((item['value'] for item in clubs if item['name'] == 'attempted_tackle_foul'), 0)),
                offsides=int(next((item['value'] for item in clubs if item['name'] == 'total_offside'), 0)),
                passes=int(next((item['value'] for item in clubs if item['name'] == 'total_pass'), 0)),
                shots=int(next((item['value'] for item in clubs if item['name'] == 'total_scoring_att'), 0)),
                shotsOnTarget=int(next((item['value'] for item in clubs if item['name'] == 'ontarget_scoring_att'), 0)),
                hitWoodwork=int(next((item['value'] for item in clubs if item['name'] == 'hit_woodwork'), 0)),
                penaltiesScored=int(next((item['value'] for item in clubs if item['name'] == 'att_pen_goal'), 0))
            )
            club_stats.append(asdict(new_club))
        except:
            print(f"Skipping entry due to missing key: {e}")
    return club_stats

# %%
def createExcel(data, stats):
    df1 = pd.DataFrame(data)
    df2 = pd.DataFrame(stats)
    df_merged = pd.concat([df1, df2], ignore_index=False, axis =1)
    df_merged.to_excel('clubs_data.xlsx', index=False, header=not os.path.exists('clubs_data.xlsx'))

# %%
def main():
    json_data = get_ClubData()
    clubs_data = parse_ClubData(json_data)
    
    json_stats = get_ClubStats(json_data)
    clubs_stats = parse_ClubStats(json_stats)

    createExcel(clubs_data, clubs_stats)

if __name__ == "__main__":
    main()
# Out:
# 12
# 1
# 10
# 4
# 21
# 11
# 7
# 23
# 2
# 25
# 20
# 3
# 26
# 9
# 34
# 13
# 6
# 29
# 27
# 36
# 42
# 38
# 5
# 14
# 19
# 22
# 31
# 43
# 39
# 131
# 45
# 17
# 15
# 35
# 37
# 127
# 33
# 28
# 18
# 8
# 41
# 130
# 40
# 16
# 46
# 32
# 159
# 44
# 30
# 24
# 163
